# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(50)

# %%
y
# Out:
# array([0.82635065, 0.17204191, 0.24485843, 0.27996233, 0.28266616,
#        0.98077791, 0.74344892, 0.37022235, 0.62547756, 0.01967944,
#        0.96464076, 0.82807526, 0.88934622, 0.7568601 , 0.7982548 ,
#        0.67605524, 0.10890567, 0.24379068, 0.12535123, 0.93065236,
#        0.72501925, 0.7337294 , 0.67887963, 0.59479527, 0.17071497,
#        0.2673104 , 0.57856696, 0.05693563, 0.80715532, 0.11760858,
#        0.73226527, 0.89701701, 0.52362695, 0.49779365, 0.63254177,
#        0.53775754, 0.51439804, 0.2553919 , 0.43808249, 0.35461134,
#        0.63327524, 0.33295648, 0.78944628, 0.31763406, 0.56771495,
#        0.81353667, 0.49413167, 0.08984794, 0.7311315 , 0.46067851])

# %%
plt.plot(y)

# %%
x = np.linspace(0, 10, 100)  #描點法第一步（起始值，結束值，多少點）

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x, np.sin(x) +x) #直接對x計算相應函數值，搭配plt.plot()就能畫圖

# %%
plt.plot(x, np.sin(x) + x)
plt.plot(x, np.cos(x))
